# %%
cd /content/drive/MyDrive/Colab Notebooks/commit/CA
# Out:
# /content/drive/MyDrive/Colab Notebooks/commit/CA

# %%
# !git config --global user.email 'rhtlsgud10@gmail.com'
# !git config --global user.name 'Shinhyung-Ko'

# %%
# !git add --all

# %%
# !git commit -m 'coin crawling'
# !git push
# Out:
# [main 2da177d] coin crawling
#  6 files changed, 5 insertions(+), 5 deletions(-)
#  rewrite Web_crawling_with_Python.ipynb (92%)
#  rewrite crawler1.ipynb (99%)
#  rewrite crawler2.ipynb (98%)
#  delete mode 100644 hello.ipynb
#  create mode 100644 mac_bit.ipynb
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 155.65 KiB | 4.58 MiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/Shinhyung-Ko/CA.git
#    2758c7a..2da177d  main -> main
