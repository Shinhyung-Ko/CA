# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/commit/CA
# Out:
# /content/drive/MyDrive/Colab Notebooks/commit/CA

# %%
# !git config --global user.email 'rhtlsgud10@gmail.com'
# !git config --global user.name 'Shinhyung-Ko'

# %%
# !git add --all

# %%
# !git commit -m '1st crawler'
# !git push
# Out:
# [main be2e614] 1st crawler
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite crawler1.ipynb (92%)
#  rewrite "def \341\204\213\341\205\247\341\206\253\341\204\211\341\205\263\341\206\270.ipynb" (87%)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.86 KiB | 272.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/Shinhyung-Ko/CA.git
#    75c9c4a..be2e614  main -> main

# %%
pip install requests

# %%
pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=86bf1908e982d62effe772f670e5fd92d860cea7053b125fc8407fa6fa91cec9
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %%
import requests as rq #파이썬으로 웹 접속
from bs4 import BeautifulSoup as bs#파이썬으로 html문서 분석

# %%
#rq.get('URL') 웹 접속 방법
data = rq.get('https://finance.naver.com/')

# %%
print(data)
#response [200] -> 잘 가져왔다
#print(data.content)
#print(data.status_code) #200이 뜨면 잘 가져온거임
# Out:
# <Response [200]>

# %%
soup = bs(data.content, 'html.parser')
#print(soup)

#중요 정보 싹 뽑기!
#print(soup.find_all(태그명, 속성명))
print(soup.find_all('span',class_="num")[2].text) #class 로 찾을때는 예약어가 있기때문에 class_
#띄어쓰기는 두개의 class, 둘 중 하나만 쓰면 됨
# Out:
# 736.10

# %%
#글자 여러개 분리 되있는 경우 -> 다 찾고 .text
#글자 중간에 변수 넣기 f'글자{변수}}글자'
#class, id가 없는 경우 -> select 함수를 사용
#> soup.select('css셀렉터를 입력하여 찾기 가능') _> soup.select('.class or #_id. 암것도 안쓰면 태그)

# %%
#이미지 -> img
# 수집하고 싶으면 src=
#print(이미지['src'])

# %%
종목들 = ['005930', '066575', '005380', '035720', '034220', '003490'] #txt에 저장
