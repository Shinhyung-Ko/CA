# %%
cd /content/drive/MyDrive/Colab Notebooks/commit/CA
# Out:
# /content/drive/MyDrive/Colab Notebooks/commit/CA

# %%
# !git config --global user.email 'rhtlsgud10@gmail.com'
# !git config --global user.name 'Shinhyung-Ko'

# %%
# !git add --all

# %%
# !git commit -m 'def연습'
# !git push
# Out:
# [main 75c9c4a] def연습
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite crawler1.ipynb (95%)
#  create mode 100644 "def \341\204\213\341\205\247\341\206\253\341\204\211\341\205\263\341\206\270.ipynb"
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 2.07 KiB | 530.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/Shinhyung-Ko/CA.git
#    0c82c70..75c9c4a  main -> main

# %%
print('안녕하세요 중고차신뢰딜러 강윤지입니다')
# Out:
# 안녕하세요 중고차신뢰딜러 강윤지입니다

# %%
#함수1 = 긴 코드를 짧은 단어로 축약
def 인사() :
    print('안녕하세요 중고차신뢰딜러 강윤지입니다')
    print('\n친절히 모시겠습니다')

인사()
# Out:
# 안녕하세요 중고차신뢰딜러 강윤지입니다
#
# 친절히 모시겠습니다

# %%
#함수2 마법 모자 만들기
def 모자(구멍):
  print(구멍 + 1)

모자(123)

def 함수일(a):
  print(a**2)
  return 10 #> 함수를 실행하고 나서 10을 남긴다
def 비니(a, 구멍2):
  print(a + 구멍2)

함수일(4)
비니(2,32)
# Out:
# 124
# 16
# 34
